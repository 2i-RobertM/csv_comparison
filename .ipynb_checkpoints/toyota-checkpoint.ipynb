# %%
import pandas as pd

# %%
df_initial = pd.read_csv("toyota_cars.csv")
df_upgrade = pd.read_csv("toyota_cars_upgrade.csv")

# %%
#df_initial

df_upgrade
# Out:
#                 model    price             dimensions wheelbase seats  \
# 0               Camry  2355000  4,885 x 1,840 x 1,445         -     5
# 1       Corolla Altis  1302000  4,630 x 1,780 x 1,435     2,700     5
# 2            GR Yaris  2740000  3,995 x 1,805 x 1,455     2,560     4
# 3           Bob Prius  1114000  4,140 x 1,730 x 1,500         -     5
# 4               Prius  2436000  4,480 x 1,745 x 1,480     2,700     5
# 5                Vios   985000  4,425 x 1,730 x 1,475     2,550     5
# 6           Vios GR-S  1035000  4,467 x 1,730 x 1,475     2,550     5
# 7                Wigo   705000  3,700 x 1,600 x 1,520         -     5
# 8               Yaris  1114000  4,140 x 1,730 x 1,500         -     5
# 9       Corolla Cross  1774000  4,455 x 1,825 x 1,620         -     -
# 10         FJ Cruiser  2218000  4,670 x 1,905 x 1,830     2,690     5
# 11           Fortuner  2465000  4,795 x 1,855 x 1,835     2,745     7
# ...

# %%
print('Shape initial {0} + shape upgrade {1}'.format(df_initial.shape, df_upgrade.shape))
# Out:
# Shape initial (33, 14) + shape upgrade (29, 14)

# %%
df_initial = df_initial.add_prefix('original_')
df_upgrade = df_upgrade.add_prefix('upgrade_')

# df_initial
# df_upgrade

# %%
df_diff = pd.merge(df_initial, df_upgrade, how = "outer", left_on = "original_model", right_on = 'upgrade_model', indicator = "Exist")

# %%
df_diff
# Out:
#         original_model  original_price    original_dimensions  \
# 0                Camry       2355000.0  4,885 x 1,840 x 1,445
# 1        Corolla Altis       1302000.0  4,630 x 1,780 x 1,435
# 2             GR Yaris       2740000.0  3,995 x 1,805 x 1,455
# 3                Prius       2436000.0  4,480 x 1,745 x 1,480
# 4                 Vios        985000.0  4,425 x 1,730 x 1,475
# 5            Vios GR-S       1035000.0  4,467 x 1,730 x 1,475
# 6                 Wigo        705000.0  3,700 x 1,600 x 1,520
# 7                Yaris       1114000.0  4,140 x 1,730 x 1,500
# 8        Corolla Cross       1774000.0  4,455 x 1,825 x 1,620
# 9           FJ Cruiser       2218000.0  4,670 x 1,905 x 1,830
# 10            Fortuner       2465000.0  4,795 x 1,855 x 1,835
# 11       Fortuner GR-S       2514000.0  4,795 x 1,855 x 1,835
# 12        Land Cruiser       5672000.0  5,130 x 1,980 x 1,945
# 13  Land Cruiser Prado       4442000.0  4,840 x 1,885 x 1,890
# ...

# %%
df_diff.shape
# Out:
# (34, 29)
